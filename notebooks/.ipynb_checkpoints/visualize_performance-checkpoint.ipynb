# %% [markdown]
# # Visualize Performance

# %% [markdown]
# Let's get a look at the files

# %%
# !ls ../model_data/best*
# Out:
# ../model_data/best_maestro_model_2_1_512_0pt3_lr_5e-04_cv_0pt2.csv
# ../model_data/best_maestro_model_2_1_512_0pt4.csv
# ../model_data/best_maestro_model_2_1_512_0pt4_cn_0pt5.csv
# ../model_data/best_maestro_model_2_1_512_0pt4_cn_1pt0.csv
# ../model_data/best_maestro_model_2_1_512_0pt4_cv_0pt1.csv
# ../model_data/best_maestro_model_2_1_512_0pt4_cv_0pt2.csv
# ../model_data/best_maestro_model_2_1_512_0pt4_lr_5e-04.csv
# ../model_data/best_maestro_model_2_1_512_0pt4_lr_5e-04_cv_0pt2.csv
# ../model_data/best_maestro_model_2_1_512_0pt5_lr_5e-04_cv_0pt2.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'axes.labelsize': 'large'})

# %% [markdown]
# ### Load Data

# %%
path = '../model_data/'
filepath = path + 'best_maestro_model_2_1_512_0pt4.csv'
df_base = pd.read_csv(filepath, index_col = 'Epochs')
filepath = path + 'best_maestro_model_2_1_512_0pt4_lr_5e-04.csv'
df_lr = pd.read_csv(filepath, index_col = 'Epochs')
filepath = path + 'best_maestro_model_2_1_512_0pt4_cn_1pt0.csv'
df_cn_1 = pd.read_csv(filepath, index_col = 'Epochs')
filepath = path + 'best_maestro_model_2_1_512_0pt4_cv_0pt2.csv'
df_cv_pt2 = pd.read_csv(filepath, index_col = 'Epochs')
filepath = path + 'best_maestro_model_2_1_512_0pt4_lr_5e-04_cv_0pt2.csv'
df_lr_cv_pt2 = pd.read_csv(filepath, index_col = 'Epochs')
filepath = path + 'best_maestro_model_2_1_512_0pt3_lr_5e-04_cv_0pt2.csv'
df_lr_cv_pt2_do_pt3 = pd.read_csv(filepath, index_col = 'Epochs')
filepath = path + 'best_maestro_model_2_1_512_0pt5_lr_5e-04_cv_0pt2.csv'
df_lr_cv_pt2_do_pt5 = pd.read_csv(filepath, index_col = 'Epochs')

# %%
var_name_to_axis_name = {'maestro_loss': 'Training Loss', 'f1_score': 'Training F-measure', \
                         'precision': 'Training Precision', 'recall': 'Training Recall', \
                         'dur_error': 'Training Duration Relative Error', 'dur_loss': 'Training Duration Loss', \
                         'val_maestro_loss': 'Validation Loss', 'val_f1_score': 'Validation F-measure', \
                         'val_precision': 'Validation Precision', 'val_recall': 'Validation Recall', \
                         'val_dur_error': 'ValidationDuration Relative Error', \
                         'val_dur_loss': 'Validation Duration Loss'}

# %%
def plot_comparison(dfs, labels, var = 'val_maestro_loss', title = None, ylim = None):
    """plot lines (maximum 6) for var versus Epoch, one for each dataframe in a list of 
    dataframes(dfs) with corresponding labels. Add title (str) and ylim if passed."""
    if (len(labels) != len(dfs)):
        print('dfs and labels are different length, abort.')
        return
    colors = ['r', 'b', 'k', 'c', 'y', 'm']
    if (len(dfs) > len(colors)):
        print('Input more dataframes than available colors, abort.')
    plt.figure(figsize = (12, 6))
    for i in range(len(dfs)):
        plt.plot(dfs[i][var], colors[i], label = labels[i])
    plt.xlabel('Epoch')
    plt.ylabel(var_name_to_axis_name[var])
    if (type(title) == str):
        plt.title(title)
    if (type(ylim) == tuple):
        plt.ylim(ylim)
    plt.legend()

# %%
plot_comparison([df_base, df_lr, df_cn_1, df_cv_pt2], labels = ['base', 'lr = 5e-4', 'clipnorm = 1.0', 'clipvalue = 0.2'], \
                var = 'maestro_loss', title = 'Figure 1')

# %% [markdown]
# In Figure 1, we plot the Training Loss across Epochs. Note the blip in early training for the base model and the model with clipnorm = 1.0, which might due to the network trying to solve two tasks at once, i.e. some gradient updates may improve classification but not the duration prediction and vice versa. Unsurprisingly, the lower learning rate (half default) learns the slowest. Interestingly, it learns the training data better than the other models. As expected, all the methods we tried delayed the failure due to NaN loss.

# %%
plot_comparison([df_base, df_lr, df_cn_1, df_cv_pt2], labels = ['base', 'lr = 5e-4', 'clipnorm = 1.0', 'clipvalue = 0.2'], \
                var = 'val_maestro_loss', title = 'Figure 2')

# %% [markdown]
# In Figure 2, we plot the Validation Loss versus time for the same models. The same trends can be seen, but the training is much noisier since the network is not minimizing Validation Loss. Also note that while the lr = 5.e-4 model learned the training set better, the clipnorm = 1.0 and clipvalue = 0.2 models actually performed better on the validation set in fewer epochs. This is an interesting result which suggests gradient clipping can reduce overfitting.

# %%
plot_comparison([df_lr_cv_pt2_do_pt3, df_lr_cv_pt2, df_lr_cv_pt2_do_pt5], labels = ['dropout_rate = 0.3', 'dropout_rate = 0.4', \
                'dropout_rate = 0.5'], var = 'maestro_loss', title = 'Figure 3')

# %% [markdown]
# As expected, the training loss is more quickly learned for lower dropout_rate and it also delays the NaN failure. Note that the blip (or increase in training loss) seen here also happened in Figure 1 (though there, the blips were smaller) for the base model and with clipnorm = 1.0 during a similar stage in training.

# %%
plot_comparison([df_lr_cv_pt2_do_pt3, df_lr_cv_pt2, df_lr_cv_pt2_do_pt5], labels = ['dropout_rate = 0.3', 'dropout_rate = 0.4', \
                'dropout_rate = 0.5'], var = 'val_maestro_loss', title = 'Figure 4')

# %% [markdown]
# While lowering the dropout_rate delayed NaN failure, it also increased overfitting which prevented it from outperforming the original dropout_rate (0.4) model on the validation set. Going the other direction (dropout_rate  0.5) also did not outperform because of its premature failure by NaN loss. I halt the hyperparameter tuning here. Our best model is that with lr = 5e-4, clipnorm = 1.0, and dropout_rate = 0.4.

# %% [markdown]
# ### Further exploring the best model

# %%
# Loss and Metrics for the best model
df_lr_cv_pt2.iloc[-3]
# Out:
# maestro_loss        0.085734
# f1_score            0.480319
# precision           0.753594
# recall              0.352809
# dur_error           0.343440
# dur_loss            0.017172
# val_maestro_loss    0.092102
# val_f1_score        0.451800
# val_precision       0.697815
# val_recall          0.334340
# val_dur_error       0.244974
# val_dur_loss        0.012249
# Name: 79, dtype: float64

# %% [markdown]
# Most important of the above are the val_f1_score and the val_dur_error. We reach about 45 % F-measure which is considerbly less than the 71% achieved by [the paper](https://www.tandfonline.com/doi/full/10.1080/25765299.2019.1649972). However, note that they treated their duration prediction as another classification and present no result describing how well the durations were predicted. In our case, we reach a relative error in duration predictions of ~24.5%. Also important are val_precision and val_recall which reach ~70% and ~33.4%, respectively. This means that ~70% of the key predictions are correct and we are capturing about 1/3 of those that we should be. We could decrease the threshold (default 0.5) to improve the F-measure, but this would likely have a negative effect on the quality of the music generated by the model. The reasoning is that it is better for music generation to have a higher precision than recall than the opposite since wrong note predictions are worse than simply missing some of the right notes. The authors of the paper do not report precision and recall so we cannot compare.

# %%
plt.figure(figsize = (12, 6))
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['maestro_loss'], 'r', label = 'Training total')
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['dur_loss'], 'b', label = 'Training duration component')
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['val_maestro_loss'], 'r--', label = 'Validation total')
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['val_dur_loss'], 'b--', label = 'Validation duration component')
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()

# %% [markdown]
# Learning is very quick at first, levels out in the duration component for both sets (training and validation) before leveling out in the validation total loss near the end (NaN failure) while the total training loss was still steadily decreasing.

# %%
plt.figure(figsize = (12, 6))
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['dur_error'], 'r', label = 'Training')
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['val_dur_error'], 'b', label = 'Validation')
plt.title('Duration Error')
plt.ylabel('Relative Error')
plt.xlabel('Epochs')
plt.legend()

# %% [markdown]
# The average difference between these two lines is quite remarkable. We reach a validation relative error in duration of just under 25%.

# %%
plt.figure(figsize = (12, 6))
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['f1_score'] * 100, 'k', label = 'Training F-measure')
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['val_f1_score'] * 100, 'k--', label = 'Validation F-measure')
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['precision'] * 100, 'r', label = 'Training Precision')
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['val_precision'] * 100, 'r--', label = 'Validation Precision')
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['recall'] * 100, 'b', label = 'Training Recall')
plt.plot(df_lr_cv_pt2.index, df_lr_cv_pt2['val_recall'] * 100, 'b--', label = 'Validation Recall')
plt.title('Classification Metrics')
plt.ylabel('Percentage')
plt.xlabel('Epochs')
plt.legend()

# %% [markdown]
# From the sharp increase in Precision early on, we can see that the network quickly learns that this is a sparse classification problem. It spends the rest of training with recall (and subsequently F-measure) improving. Towards the end of training, the validation precision suffers.
